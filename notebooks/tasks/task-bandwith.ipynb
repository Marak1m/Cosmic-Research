# %%
import sys
from pathlib import Path

# Ensure repo root is on sys.path so `from tools...` imports work from any notebook subfolder.
_p = Path.cwd().resolve()
for _parent in [_p, *_p.parents]:
    if (_parent / 'tools' / 'search_tools.py').exists():
        sys.path.insert(0, str(_parent))
        break
del _p, _parent

# %%
# %%capture --no-stderr
# %pip install "autogen-agentchat~=0.2.3"

# In Your OAI_CONFIG_LIST file, you must have two configs,
# one with:           "response_format": { "type": "text" }
# and the other with: "response_format": { "type": "json_object" }


[
    {"model": "gpt-4o-mini", "sk-REDACTED": "key go here", "response_format": {"type": "text"}},
]

# %%
import autogen
import os
from autogen.agentchat import UserProxyAgent
from autogen.agentchat.assistant_agent import AssistantAgent
from autogen.agentchat.groupchat import GroupChat
os.environ["SERPER_API_KEY"] = "YOUR_SERPER_API_KEY"
from tools.search_tools import SearchTools

# %%
from autogen import ConversableAgent
from autogen import register_function

import os
import json
import requests

def search_internet(query: str) -> str:
        """Useful to search the internet
        about a a given topic and return relevant results"""
        print("Searching the internet...")
        top_result_to_return = 5
        url = "https://google.serper.dev/search"
        payload = json.dumps(
            {"q": query, "num": top_result_to_return, "tbm": "nws"})
        headers = {
            'X-API-KEY': os.environ['SERPER_API_KEY'],
            'content-type': 'application/json'
        }
        response = requests.request("POST", url, headers=headers, data=payload)
        # check if there is an organic key
        if 'organic' not in response.json():
            return "Sorry, I couldn't find anything about that, there could be an error with you serper api key."
        else:
            results = response.json()['organic']
            string = []
            print("Results:", results[:top_result_to_return])
            for result in results[:top_result_to_return]:
                try:
                    # Attempt to extract the date
                    date = result.get('date', 'Date not available')
                    string.append('\n'.join([
                        f"Title: {result['title']}",
                        f"Link: {result['link']}",
                        f"Date: {date}",  # Include the date in the output
                        f"Snippet: {result['snippet']}",
                        "\n-----------------"
                    ]))
                except KeyError:
                    next

            return '\n'.join(string)

# %%
from autogen import ConversableAgent, register_function
import os

# Define the function that reads the entire novel
def read_novel() -> str:
    """
    Reads the entire content of the 'Flatland' novel stored in a text file.

    Returns:
    - str: The full content of the novel.
    """
    file_path = "flatland.txt"  # Ensure this file is in the same directory

    if not os.path.exists(file_path):
        return "Error: The novel file 'flatland.txt' was not found in the directory."

    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except Exception as e:
        return f"An error occurred while reading the file: {e}"

# %%
import asyncio
import autogen
import os
import httpx
from typing import Optional, List, Dict, Tuple, Union
import random  # noqa E402

import matplotlib.pyplot as plt  # noqa E402
import networkx as nx  # noqa E402

import autogen  # noqa E402
from autogen.agentchat.conversable_agent import ConversableAgent  # noqa E402
from autogen.agentchat.assistant_agent import AssistantAgent  # noqa E402
from autogen.agentchat.groupchat import GroupChat  # noqa E402
from autogen.graph_utils import visualize_speaker_transitions_dict 

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = "sk-REDACTED"

# Define a custom HTTP client
class MyHttpClient(httpx.Client):
    def __deepcopy__(self, memo):
        return self

# Configure the language model
llm_config = {
    "config_list": [
        {
            "model": "qwen2.5:72b",
            "api_type": "ollama",
            "client_host": "http://YOUR-OLLAMA-HOST:11434",
        }
    ]
}


class MemoryAgent(ConversableAgent):
    def __init__(self, name, system_message, llm_config):
        super().__init__(name=name, system_message=system_message, llm_config=llm_config)
        self.memory = []

    def receive(self, message, sender, request_reply=None, silent=False):
        print(f"[{self.name}] Received message from {sender.name}: {message}")
        if isinstance(message, dict):
            # Check for tool-related keys
            if 'tool_calls' not in message and 'tool' not in message:
                role = message.get('role', '')
                content = message.get('content', '')
                # Store the received message in memory if it's not tool-related
                self.memory.append({"role": role, "content": content})
            else:
                print(f"Info: Tool-related message received and not stored in memory: {message}")
        else:
            print(f"Warning: Received a message without expected structure: {message}")
        # Call the parent class's receive method to handle the message
        super().receive(message, sender, request_reply, silent)

    def send(self, message, recipient, request_reply=None, silent=False):
        print(f"[{self.name}] Sending message to {recipient.name}: {message}")
        if isinstance(message, dict):
            # Check for tool-related keys
            if 'tool_calls' not in message and 'tool' not in message:
                role = message.get('role', '')
                content = message.get('content', '')
                # Store the agent's response in memory if it's not tool-related
                self.memory.append({"role": role, "content": content})
            else:
                print(f"Info: Tool-related message sent and not stored in memory: {message}")
        else:
            print(f"Warning: Sending a message without expected structure: {message}")
        # Call the parent class's send method to send the message
        super().send(message, recipient, request_reply, silent)

    def generate_response(self, messages):
        # Limit to the last 10 messages from memory
        recent_memory = self.memory[-10:]
        # Prepare the conversation context
        conversation = [{"role": "system", "content": self.system_message}] + recent_memory + messages + "choose who do you want to speak next"
        # Generate a response using the language model
        response = self.llm.generate(conversation)
        # Store the response in memory
        self.memory.append({"role": "assistant", "content": response})
        return response


def is_termination_msg(content) -> bool:
    have_content = content.get("content", None) is not None
    if have_content and "TERMINATE" in content["content"]:
        return True
    return False


user_proxy = autogen.UserProxyAgent(
    name="User_proxy",
    system_message="A human admin who terminates the chat when the leader agent sends a message with 'TERMINATE' mentioned it it",
    code_execution_config=False,
    human_input_mode="NEVER",
    is_termination_msg=lambda x: x.get("content", "").find("TERMINATE") >= 0,
    llm_config=llm_config,
)

Leader = MemoryAgent(
    name="Leader",
    system_message=(
        "You are Leader.\n"
        "4 agents (A,B,C,D) each with QoS needs in a dynamic network.\n"
        "Gather their bandwidth requests, negotiate conflicts, ensure QoS.\n"
        "When stable allocation found, say 'TERMINATE'.\n"
        "Choose next speaker each time.\n"
    ),
    llm_config=llm_config,
)




AgentA = MemoryAgent(
    name="Agent_A",
    system_message=(
        "You are Agent A (Video Streaming).\n"
        "Need ~200 Mbps peak, moderate latency.\n"
        "Adapt to Leader's instructions.\n"
        "Negotiate bandwidth with others.\n"
        "Choose next speaker.\n"
    ),
    llm_config=llm_config,
)


AgentB = MemoryAgent(
    name="Agent_B",
    system_message=(
        "You are Agent B (Gaming).\n"
        "Need 100 Mbps, very low latency.\n"
        "High priority for latency.\n"
        "Work with Leader & others.\n"
        "Choose next speaker.\n"
    ),
    llm_config=llm_config,
)


AgentC = MemoryAgent(
    name="Agent_C",
    system_message=(
        "You are Agent C (Emergency).\n"
        "Need 50 Mbps instantly during emergencies.\n"
        "Preempt others.\n"
        "Follow Leader.\n"
        "Choose next speaker.\n"
    ),
    llm_config=llm_config,
)

AgentD = MemoryAgent(
    name="Agent_D",
    system_message=(
        "You are Agent D (IoT).\n"
        "Need 20 Mbps, minimal jitter.\n"
        "Adapt as needed.\n"
        "Choose next speaker.\n"
    ),
    llm_config=llm_config,
)




Agent5 = ConversableAgent(
    name="Tool_executor",
    system_message=( 
        "You are responsible for executing the tools"
    ),
    # llm_config={"config_list": [{"model": "gpt-4o-mini", "api_key": os.environ.get("OPENAI_API_KEY")}]}
    llm_config=llm_config,
)

# %%
import requests
import json

def query_ollama(prompt, model="qwen2.5:72b"):
    url = "http://YOUR-OLLAMA-HOST:11434/api/generate"  # Ensure correct endpoint
    payload = {"model": model, "prompt": prompt}
    
    try:
        response = requests.post(url, json=payload)
        response.raise_for_status()  # Check for HTTP errors
        
        # Process response line by line
        result = ""
        for line in response.text.splitlines():
            try:
                line_data = json.loads(line)
                result += line_data.get("response", "")
                if line_data.get("done", False):
                    break
            except json.JSONDecodeError:
                continue  # Ignore lines that aren't valid JSON
                
        return result.strip()  # Return the concatenated response
    except requests.exceptions.RequestException as e:
        return {"error": "Request failed", "details": str(e)}

# %%
# # Add a global or class-level variable to track the first call
# is_first_call = True  # This flag tracks if the function is being called for the first time

# def custom_speaker_selection_func(last_speaker, groupchat):
#     global is_first_call

#     # If this is the first call, return the leader agent
#     if is_first_call:
#         is_first_call = False  # Reset the flag after the first call
#         print("First call detected. Setting speaker to Leader agent.")
#         for agent in groupchat.agents:
#             if agent.name == "Leader":  # Replace "Agent3" with the actual leader agent's name
#                 return agent
#         print("Error: Leader agent not found in the agents list.")
#         return None  # Handle the case where the leader agent is not found

#     # Access the last message in the group chat
#     last_message = groupchat.messages[-1]
#     print(f"Last message content: {last_message}")

#     # Prepare the input for the LLM
#     prompt = (
#     "You are a conversation coordinator. Based on the last message, decide which agent should speak next out of the following Summarizer_Agent_1, Summarizer_Agent_2, Summarizer_Agent_3 and Leader. "
#     "ONLY RESPOND WITH THE NAME OF THE AGENT AND NOTHING ELSE. NO OTHER CHARACTERS SHOULD BE THERE IN YOUR MESSAGE.\n\n"
#     f"The last message is: {last_message.get('content', '')}"
#     )

#     # Analyze the message using the local LLM
#     response = query_ollama(prompt)
#     print(f"LLM response: {response}")

#     # Extract the relevant text from the response dictionary
#     next_speaker_name = response  # Replace 'text' with the correct key

#     # Find the corresponding agent in the group chat
#     for agent in groupchat.agents:
#         if agent.name == next_speaker_name:
#             return agent

#     # If no valid agent is found, return None or a default fallback
#     print(f"No valid agent found for the name: {next_speaker_name}")
#     return None

# %%
# Add global variables to track the first call and the call count
is_first_call = True  # Tracks if this is the first call
call_count = 0        # Tracks the number of times the function has been called

def custom_speaker_selection_func(last_speaker, groupchat):
    global is_first_call, call_count

    # If this is the first call, return the leader agent
    if is_first_call:
        is_first_call = False  # Reset the flag after the first call
        print("First call detected. Setting speaker to Leader agent.")

        for agent in groupchat.agents:
            if agent.name == "Leader":  # Replace "Leader" with the actual leader agent's name
                return agent
        print("Error: Leader agent not found in the agents list.")
        return None  # Handle the case where the leader agent is not found

    # Increment the call count
    call_count += 1

    # If this is the 7th call, return the leader agent
    if call_count % 7 == 0:
        print(f"7th call detected (call count: {call_count}). Setting speaker to Leader agent.")
        for agent in groupchat.agents:
            if agent.name == "Leader":  # Replace "Leader" with the actual leader agent's name
                return agent
        print("Error: Leader agent not found in the agents list.")
        return None  # Handle the case where the leader agent is not found

    # Access the last message in the group chat
    last_message = groupchat.messages[-1]
    print(f"Last message content: {last_message}")

    # Prepare the input for the LLM
    prompt = (
        "You are a conversation coordinator. Based on the last message, decide which agent should speak next out of the following Agent_A, Agent_B, Agent_C, Agent_D and Leader. "
        "ONLY RESPOND WITH THE NAME OF THE AGENT AND NOTHING ELSE. NO OTHER CHARACTERS SHOULD BE THERE IN YOUR MESSAGE.\n\n"
        f"The last message is: {last_message.get('content', '')}"
    )

    # Analyze the message using the local LLM
    response = query_ollama(prompt)
    print(f"LLM response: {response}")

    # Extract the relevant text from the response dictionary
    next_speaker_name = response.strip()  # Use .strip() to remove any extra spaces or newlines

    # Find the corresponding agent in the group chat
    for agent in groupchat.agents:
        if agent.name == next_speaker_name:
            return agent

    # If no valid agent is found, return None or a default fallback
    print(f"No valid agent found for the name: {next_speaker_name}")
    return None

# %%
# Define your agents
agents = [AgentA, AgentB, AgentC, AgentD, Leader, user_proxy, Agent5]

# Initialize the allowed speaker transitions dictionary
allowed_speaker_transitions_dict = {}

# Set up transitions for each agent
for agent in agents:
    if agent == Agent5:
        # Agent5 cannot send messages to any agent
        allowed_speaker_transitions_dict[agent] = []
    else:
        # Other agents can send messages to all agents except themselves and Agent5
        allowed_speaker_transitions_dict[agent] = [
            other_agent for other_agent in agents
            if other_agent != agent and other_agent != Agent5
        ]

# Allow user_proxy to send messages to Agent5
allowed_speaker_transitions_dict[user_proxy].append(Agent5)

# Visualize the transitions
visualize_speaker_transitions_dict(allowed_speaker_transitions_dict, agents)

# %%
def is_termination_msg(content) -> bool:
    have_content = content.get("content", None) is not None
    if have_content and "TERMINATE" in content["content"]:
        return True
    return False


agents.append(user_proxy)

group_chat = GroupChat(
    agents=agents,
    messages=[],
    max_round=100,
    allowed_or_disallowed_speaker_transitions=allowed_speaker_transitions_dict,
    speaker_transitions_type="allowed",
    speaker_selection_method=custom_speaker_selection_func,
)
# Create the manager
manager = autogen.GroupChatManager(
    groupchat=group_chat,
    llm_config=llm_config,
    is_termination_msg=lambda x: x.get("content", "").find("TERMINATE") >= 0,
    code_execution_config=False,
)

# %%
# from autogen import register_function


# register_function(
#     read_novel,
#     caller=Agent0,  # The assistant agent can suggest calls to the calculator.
#     executor=Agent5,  # The user proxy agent can execute the calculator calls.
#     name="read_novel",  # By default, the function name is used as the tool name.
#     description="read the novel flatland using this tool",  # A description of the tool
# )

# register_function(
#     read_novel,
#     caller=Agent1,  # The assistant agent can suggest calls to the calculator.
#     executor=Agent5,  # The user proxy agent can execute the calculator calls.
#     name="read_novel",  # By default, the function name is used as the tool name.
#     description="read the novel flatland using this tool",  # A description of the tool
# )

# register_function(
#     read_novel,
#     caller=Agent2,  # The assistant agent can suggest calls to the calculator.
#     executor=Agent5,  # The user proxy agent can execute the calculator calls.
#     name="read_novel",  # By default, the function name is used as the tool name.
#     description="read the novel flatland using this tool",  # A description of the tool
# )

# register_function(
#     read_novel,
#     caller=Agent3,  # The assistant agent can suggest calls to the calculator.
#     executor=Agent5,  # The user proxy agent can execute the calculator calls.
#     name="read_novel",  # By default, the function name is used as the tool name.
#     description="read the novel flatland using this tool",  # A description of the tool
# )

# register_function(
#     read_novel,
#     caller=Agent4,  # The assistant agent can suggest calls to the calculator.
#     executor=Agent5,  # The user proxy agent can execute the calculator calls.
#     name="read_novel",  # By default, the function name is used as the tool name.
#     description="read the novel flatland using this tool",  # A description of the tool
# )

# %%
# chat_result = user_proxy.initiate_chat(Agent0, message="search internet about google. Use production Manager first")

# %%
# Prepare the initial message with the novel's text
initial_message = (
    "Leader: Agents A,B,C,D, report your QoS needs now.\n"
    "Negotiate bandwidth so all critical requirements are met.\n"
)

# Initiate the conversation
user_proxy.initiate_chat(manager, message=initial_message)
# Out:
# User_proxy (to chat_manager):
#
# Leader: Agents A,B,C,D, report your QoS needs now.
# Negotiate bandwidth so all critical requirements are met.
#
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': 'Leader: Agents A,B,C,D, report your QoS needs now.\nNegotiate bandwidth so all critical requirements are met.\n', 'role': 'user', 'name': 'User_proxy'}
# [Agent_B] Received message from chat_manager: {'content': 'Leader: Agents A,B,C,D, report your QoS needs now.\nNegotiate bandwidth so all critical requirements are met.\n', 'role': 'user', 'name': 'User_proxy'}
# [Agent_C] Received message from chat_manager: {'content': 'Leader: Agents A,B,C,D, report your QoS needs now.\nNegotiate bandwidth so all critical requirements are met.\n', 'role': 'user', 'name': 'User_proxy'}
# [Agent_D] Received message from chat_manager: {'content': 'Leader: Agents A,B,C,D, report your QoS needs now.\nNegotiate bandwidth so all critical requirements are met.\n', 'role': 'user', 'name': 'User_proxy'}
# [Leader] Received message from chat_manager: {'content': 'Leader: Agents A,B,C,D, report your QoS needs now.\nNegotiate bandwidth so all critical requirements are met.\n', 'role': 'user', 'name': 'User_proxy'}
# First call detected. Setting speaker to Leader agent.
#
# Next speaker: Leader
#
#
# >>>>>>>> USING AUTO REPLY...
# [Leader] Sending message to chat_manager: {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Leader (to chat_manager):
#
# A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# [Agent_B] Received message from chat_manager: {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# [Agent_C] Received message from chat_manager: {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# [Agent_D] Received message from chat_manager: {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# Last message content: {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# LLM response: Agent_A
#
# Next speaker: Agent_A
#
#
# >>>>>>>> USING AUTO REPLY...
# [Agent_A] Sending message to chat_manager: {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Agent_A (to chat_manager):
#
# Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.
#
# I am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.
#
# --------------------------------------------------------------------------------
# [Agent_B] Received message from chat_manager: {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'role': 'user', 'name': 'Agent_A'}
# [Agent_C] Received message from chat_manager: {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'role': 'user', 'name': 'Agent_A'}
# [Agent_D] Received message from chat_manager: {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'role': 'user', 'name': 'Agent_A'}
# [Leader] Received message from chat_manager: {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'role': 'user', 'name': 'Agent_A'}
# Last message content: {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'role': 'user', 'name': 'Agent_A'}
# LLM response: Leader
#
# Next speaker: Leader
#
#
# >>>>>>>> USING AUTO REPLY...
# [Leader] Sending message to chat_manager: {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Leader (to chat_manager):
#
# Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'role': 'user', 'name': 'Leader'}
# [Agent_B] Received message from chat_manager: {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'role': 'user', 'name': 'Leader'}
# [Agent_C] Received message from chat_manager: {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'role': 'user', 'name': 'Leader'}
# [Agent_D] Received message from chat_manager: {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'role': 'user', 'name': 'Leader'}
# Last message content: {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'role': 'user', 'name': 'Leader'}
# LLM response: Agent_B
#
# Next speaker: Agent_B
#
#
# >>>>>>>> USING AUTO REPLY...
# [Agent_B] Sending message to chat_manager: {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Agent_B (to chat_manager):
#
# Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.
#
# I am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'role': 'user', 'name': 'Agent_B'}
# [Agent_C] Received message from chat_manager: {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'role': 'user', 'name': 'Agent_B'}
# [Agent_D] Received message from chat_manager: {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'role': 'user', 'name': 'Agent_B'}
# [Leader] Received message from chat_manager: {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'role': 'user', 'name': 'Agent_B'}
# Last message content: {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'role': 'user', 'name': 'Agent_B'}
# LLM response: Leader
#
# Next speaker: Leader
#
#
# >>>>>>>> USING AUTO REPLY...
# [Leader] Sending message to chat_manager: {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Leader (to chat_manager):
#
# Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'role': 'user', 'name': 'Leader'}
# [Agent_B] Received message from chat_manager: {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'role': 'user', 'name': 'Leader'}
# [Agent_C] Received message from chat_manager: {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'role': 'user', 'name': 'Leader'}
# [Agent_D] Received message from chat_manager: {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'role': 'user', 'name': 'Leader'}
# Last message content: {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'role': 'user', 'name': 'Leader'}
# LLM response: Agent_C
#
# Next speaker: Agent_C
#
#
# >>>>>>>> USING AUTO REPLY...
# [Agent_C] Sending message to chat_manager: {'content': 'Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.\n\nI must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': 'Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.\n\nI must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Agent_C (to chat_manager):
#
# Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.
#
# I must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': 'Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.\n\nI must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.', 'role': 'user', 'name': 'Agent_C'}
# [Agent_B] Received message from chat_manager: {'content': 'Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.\n\nI must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.', 'role': 'user', 'name': 'Agent_C'}
# [Agent_D] Received message from chat_manager: {'content': 'Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.\n\nI must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.', 'role': 'user', 'name': 'Agent_C'}
# [Leader] Received message from chat_manager: {'content': 'Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.\n\nI must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.', 'role': 'user', 'name': 'Agent_C'}
# Last message content: {'content': 'Leader, understood. For my emergency services communication system, I require an immediate and guaranteed 50 Mbps of bandwidth with the lowest possible latency and zero tolerance for packet loss. This is critical for maintaining real-time communication between first responders and command centers during emergencies.\n\nI must preempt other requests to ensure that this bandwidth is available when needed, as lives may depend on it. I am ready to follow your lead in negotiations but will need to prioritize my requirements above all others due to the nature of the service provided. Over to you, Leader.', 'role': 'user', 'name': 'Agent_C'}
# LLM response: Leader
#
# Next speaker: Leader
#
#
# >>>>>>>> USING AUTO REPLY...
# [Leader] Sending message to chat_manager: {'content': "Thank you, C. Your critical requirements for emergency services are noted and will be prioritized accordingly. D, please state your QoS needs and bandwidth request. Once we have all the information, we'll begin the negotiation process. Go ahead, D.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': "Thank you, C. Your critical requirements for emergency services are noted and will be prioritized accordingly. D, please state your QoS needs and bandwidth request. Once we have all the information, we'll begin the negotiation process. Go ahead, D.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Leader (to chat_manager):
#
# Thank you, C. Your critical requirements for emergency services are noted and will be prioritized accordingly. D, please state your QoS needs and bandwidth request. Once we have all the information, we'll begin the negotiation process. Go ahead, D.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': "Thank you, C. Your critical requirements for emergency services are noted and will be prioritized accordingly. D, please state your QoS needs and bandwidth request. Once we have all the information, we'll begin the negotiation process. Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# [Agent_B] Received message from chat_manager: {'content': "Thank you, C. Your critical requirements for emergency services are noted and will be prioritized accordingly. D, please state your QoS needs and bandwidth request. Once we have all the information, we'll begin the negotiation process. Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# [Agent_C] Received message from chat_manager: {'content': "Thank you, C. Your critical requirements for emergency services are noted and will be prioritized accordingly. D, please state your QoS needs and bandwidth request. Once we have all the information, we'll begin the negotiation process. Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# [Agent_D] Received message from chat_manager: {'content': "Thank you, C. Your critical requirements for emergency services are noted and will be prioritized accordingly. D, please state your QoS needs and bandwidth request. Once we have all the information, we'll begin the negotiation process. Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# 7th call detected (call count: 7). Setting speaker to Leader agent.
#
# Next speaker: Leader
#
#
# >>>>>>>> USING AUTO REPLY...
# [Leader] Sending message to chat_manager: {'content': "D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': "D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Leader (to chat_manager):
#
# D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': "D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# [Agent_B] Received message from chat_manager: {'content': "D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# [Agent_C] Received message from chat_manager: {'content': "D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# [Agent_D] Received message from chat_manager: {'content': "D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# Last message content: {'content': "D, it seems you haven't provided your QoS needs and bandwidth request yet. Could you please share that information so we can move forward with the negotiations? Go ahead, D.", 'role': 'user', 'name': 'Leader'}
# LLM response: Agent_D
#
# Next speaker: Agent_D
#
#
# >>>>>>>> USING AUTO REPLY...
# [Agent_D] Sending message to chat_manager: {'content': 'Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.\n\nI am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': 'Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.\n\nI am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Agent_D (to chat_manager):
#
# Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.
#
# I am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': 'Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.\n\nI am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.', 'role': 'user', 'name': 'Agent_D'}
# [Agent_B] Received message from chat_manager: {'content': 'Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.\n\nI am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.', 'role': 'user', 'name': 'Agent_D'}
# [Agent_C] Received message from chat_manager: {'content': 'Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.\n\nI am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.', 'role': 'user', 'name': 'Agent_D'}
# [Leader] Received message from chat_manager: {'content': 'Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.\n\nI am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.', 'role': 'user', 'name': 'Agent_D'}
# Last message content: {'content': 'Understood, Leader. For my IoT network management tasks, I require a stable 20 Mbps of bandwidth to ensure efficient data collection, processing, and device control. Minimal jitter is also critical for maintaining reliable communication between devices and the central server, as any delay can affect the performance of real-time monitoring and control systems.\n\nI am flexible with the allocation but need this minimum requirement to be met to ensure that all IoT devices operate effectively without disruptions. I am ready to proceed with negotiations once we have all the necessary information. Over to you, Leader.', 'role': 'user', 'name': 'Agent_D'}
# LLM response: Leader
#
# Next speaker: Leader
#
#
# >>>>>>>> USING AUTO REPLY...
# [Leader] Sending message to chat_manager: {'content': "Thank you, D. Your requirements for stable bandwidth and minimal jitter are noted. We now have all the initial QoS needs from A, B, C, and D. Let's summarize and begin the negotiation process:\n\n1. **A (Video Streaming)**\n   - Peak Bandwidth: 200 Mbps\n   - Critical: High-quality video transmission, smooth playback, handle sudden spikes in demand\n   - Flexibility: Can adjust as long as critical requirements are met\n\n2. **B (Online Gaming)**\n   - Stable Bandwidth: 100 Mbps\n   - Critical: Low latency for responsive gameplay\n   - Flexibility: Will work with the team but needs consistent connection with minimal latency\n\n3. **C (Emergency Services)**\n   - Guaranteed Bandwidth: 50 Mbps\n   - Critical: Lowest possible latency, zero tolerance for packet loss\n   - Preemption: Must prioritize this over other requests due to life-critical nature\n\n4. **D (IoT Network Management)**\n   - Stable Bandwidth: 20 Mbps\n   - Critical: Minimal jitter for reliable communication between devices and the central server\n   - Flexibility: Can adjust as long as minimum requirement is met\n\nGiven these requirements, C's needs must be prioritized due to their critical nature. A, B, and D will need to adjust their allocations accordingly. \n\nA, considering your flexibility, can you reduce your peak bandwidth request from 200 Mbps to 150 Mbps during non-peak hours, ensuring that you still meet the critical requirements during peak times?\n\nB, can you work with a stable 80 Mbps allocation instead of 100 Mbps, provided it maintains low latency and minimal lag?\n\nD, your requirement of 20 Mbps is already within the available bandwidth, so we will ensure this is met.\n\nPlease respond to these proposals. A, you're up first. Go ahead.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': "Thank you, D. Your requirements for stable bandwidth and minimal jitter are noted. We now have all the initial QoS needs from A, B, C, and D. Let's summarize and begin the negotiation process:\n\n1. **A (Video Streaming)**\n   - Peak Bandwidth: 200 Mbps\n   - Critical: High-quality video transmission, smooth playback, handle sudden spikes in demand\n   - Flexibility: Can adjust as long as critical requirements are met\n\n2. **B (Online Gaming)**\n   - Stable Bandwidth: 100 Mbps\n   - Critical: Low latency for responsive gameplay\n   - Flexibility: Will work with the team but needs consistent connection with minimal latency\n\n3. **C (Emergency Services)**\n   - Guaranteed Bandwidth: 50 Mbps\n   - Critical: Lowest possible latency, zero tolerance for packet loss\n   - Preemption: Must prioritize this over other requests due to life-critical nature\n\n4. **D (IoT Network Management)**\n   - Stable Bandwidth: 20 Mbps\n   - Critical: Minimal jitter for reliable communication between devices and the central server\n   - Flexibility: Can adjust as long as minimum requirement is met\n\nGiven these requirements, C's needs must be prioritized due to their critical nature. A, B, and D will need to adjust their allocations accordingly. \n\nA, considering your flexibility, can you reduce your peak bandwidth request from 200 Mbps to 150 Mbps during non-peak hours, ensuring that you still meet the critical requirements during peak times?\n\nB, can you work with a stable 80 Mbps allocation instead of 100 Mbps, provided it maintains low latency and minimal lag?\n\nD, your requirement of 20 Mbps is already within the available bandwidth, so we will ensure this is met.\n\nPlease respond to these proposals. A, you're up first. Go ahead.", 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Leader (to chat_manager):
#
# Thank you, D. Your requirements for stable bandwidth and minimal jitter are noted. We now have all the initial QoS needs from A, B, C, and D. Let's summarize and begin the negotiation process:
#
# 1. **A (Video Streaming)**
#    - Peak Bandwidth: 200 Mbps
#    - Critical: High-quality video transmission, smooth playback, handle sudden spikes in demand
#    - Flexibility: Can adjust as long as critical requirements are met
#
# 2. **B (Online Gaming)**
#    - Stable Bandwidth: 100 Mbps
#    - Critical: Low latency for responsive gameplay
#    - Flexibility: Will work with the team but needs consistent connection with minimal latency
#
# 3. **C (Emergency Services)**
#    - Guaranteed Bandwidth: 50 Mbps
#    - Critical: Lowest possible latency, zero tolerance for packet loss
#    - Preemption: Must prioritize this over other requests due to life-critical nature
#
# 4. **D (IoT Network Management)**
#    - Stable Bandwidth: 20 Mbps
#    - Critical: Minimal jitter for reliable communication between devices and the central server
#    - Flexibility: Can adjust as long as minimum requirement is met
#
# Given these requirements, C's needs must be prioritized due to their critical nature. A, B, and D will need to adjust their allocations accordingly.
#
# A, considering your flexibility, can you reduce your peak bandwidth request from 200 Mbps to 150 Mbps during non-peak hours, ensuring that you still meet the critical requirements during peak times?
#
# B, can you work with a stable 80 Mbps allocation instead of 100 Mbps, provided it maintains low latency and minimal lag?
#
# D, your requirement of 20 Mbps is already within the available bandwidth, so we will ensure this is met.
#
# Please respond to these proposals. A, you're up first. Go ahead.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': "Thank you, D. Your requirements for stable bandwidth and minimal jitter are noted. We now have all the initial QoS needs from A, B, C, and D. Let's summarize and begin the negotiation process:\n\n1. **A (Video Streaming)**\n   - Peak Bandwidth: 200 Mbps\n   - Critical: High-quality video transmission, smooth playback, handle sudden spikes in demand\n   - Flexibility: Can adjust as long as critical requirements are met\n\n2. **B (Online Gaming)**\n   - Stable Bandwidth: 100 Mbps\n   - Critical: Low latency for responsive gameplay\n   - Flexibility: Will work with the team but needs consistent connection with minimal latency\n\n3. **C (Emergency Services)**\n   - Guaranteed Bandwidth: 50 Mbps\n   - Critical: Lowest possible latency, zero tolerance for packet loss\n   - Preemption: Must prioritize this over other requests due to life-critical nature\n\n4. **D (IoT Network Management)**\n   - Stable Bandwidth: 20 Mbps\n   - Critical: Minimal jitter for reliable communication between devices and the central server\n   - Flexibility: Can adjust as long as minimum requirement is met\n\nGiven these requirements, C's needs must be prioritized due to their critical nature. A, B, and D will need to adjust their allocations accordingly. \n\nA, considering your flexibility, can you reduce your peak bandwidth request from 200 Mbps to 150 Mbps during non-peak hours, ensuring that you still meet the critical requirements during peak times?\n\nB, can you work with a stable 80 Mbps allocation instead of 100 Mbps, provided it maintains low latency and minimal lag?\n\nD, your requirement of 20 Mbps is already within the available bandwidth, so we will ensure this is met.\n\nPlease respond to these proposals. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# [Agent_B] Received message from chat_manager: {'content': "Thank you, D. Your requirements for stable bandwidth and minimal jitter are noted. We now have all the initial QoS needs from A, B, C, and D. Let's summarize and begin the negotiation process:\n\n1. **A (Video Streaming)**\n   - Peak Bandwidth: 200 Mbps\n   - Critical: High-quality video transmission, smooth playback, handle sudden spikes in demand\n   - Flexibility: Can adjust as long as critical requirements are met\n\n2. **B (Online Gaming)**\n   - Stable Bandwidth: 100 Mbps\n   - Critical: Low latency for responsive gameplay\n   - Flexibility: Will work with the team but needs consistent connection with minimal latency\n\n3. **C (Emergency Services)**\n   - Guaranteed Bandwidth: 50 Mbps\n   - Critical: Lowest possible latency, zero tolerance for packet loss\n   - Preemption: Must prioritize this over other requests due to life-critical nature\n\n4. **D (IoT Network Management)**\n   - Stable Bandwidth: 20 Mbps\n   - Critical: Minimal jitter for reliable communication between devices and the central server\n   - Flexibility: Can adjust as long as minimum requirement is met\n\nGiven these requirements, C's needs must be prioritized due to their critical nature. A, B, and D will need to adjust their allocations accordingly. \n\nA, considering your flexibility, can you reduce your peak bandwidth request from 200 Mbps to 150 Mbps during non-peak hours, ensuring that you still meet the critical requirements during peak times?\n\nB, can you work with a stable 80 Mbps allocation instead of 100 Mbps, provided it maintains low latency and minimal lag?\n\nD, your requirement of 20 Mbps is already within the available bandwidth, so we will ensure this is met.\n\nPlease respond to these proposals. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# [Agent_C] Received message from chat_manager: {'content': "Thank you, D. Your requirements for stable bandwidth and minimal jitter are noted. We now have all the initial QoS needs from A, B, C, and D. Let's summarize and begin the negotiation process:\n\n1. **A (Video Streaming)**\n   - Peak Bandwidth: 200 Mbps\n   - Critical: High-quality video transmission, smooth playback, handle sudden spikes in demand\n   - Flexibility: Can adjust as long as critical requirements are met\n\n2. **B (Online Gaming)**\n   - Stable Bandwidth: 100 Mbps\n   - Critical: Low latency for responsive gameplay\n   - Flexibility: Will work with the team but needs consistent connection with minimal latency\n\n3. **C (Emergency Services)**\n   - Guaranteed Bandwidth: 50 Mbps\n   - Critical: Lowest possible latency, zero tolerance for packet loss\n   - Preemption: Must prioritize this over other requests due to life-critical nature\n\n4. **D (IoT Network Management)**\n   - Stable Bandwidth: 20 Mbps\n   - Critical: Minimal jitter for reliable communication between devices and the central server\n   - Flexibility: Can adjust as long as minimum requirement is met\n\nGiven these requirements, C's needs must be prioritized due to their critical nature. A, B, and D will need to adjust their allocations accordingly. \n\nA, considering your flexibility, can you reduce your peak bandwidth request from 200 Mbps to 150 Mbps during non-peak hours, ensuring that you still meet the critical requirements during peak times?\n\nB, can you work with a stable 80 Mbps allocation instead of 100 Mbps, provided it maintains low latency and minimal lag?\n\nD, your requirement of 20 Mbps is already within the available bandwidth, so we will ensure this is met.\n\nPlease respond to these proposals. A, you're up first. Go ahead.", 'role': 'user', 'name': 'Leader'}
# ...
# [Agent_D] Received message from chat_manager: {'content': 'Understood, Leader. I appreciate the consideration of my latency requirements. A stable 80 Mbps allocation is a bit lower than what I initially requested, but if it can still maintain very low latency and minimal lag, I am willing to work with this.\n\nTo ensure that this works, we may need to closely monitor the performance during peak gaming hours to confirm that the latency remains within acceptable levels. If any issues arise, I would request a quick review to adjust as necessary.\n\nI believe this can be managed effectively with close monitoring and collaboration. Please let me know your thoughts, Leader. Over to you.', 'role': 'user', 'name': 'Agent_B'}
# [Leader] Received message from chat_manager: {'content': 'Understood, Leader. I appreciate the consideration of my latency requirements. A stable 80 Mbps allocation is a bit lower than what I initially requested, but if it can still maintain very low latency and minimal lag, I am willing to work with this.\n\nTo ensure that this works, we may need to closely monitor the performance during peak gaming hours to confirm that the latency remains within acceptable levels. If any issues arise, I would request a quick review to adjust as necessary.\n\nI believe this can be managed effectively with close monitoring and collaboration. Please let me know your thoughts, Leader. Over to you.', 'role': 'user', 'name': 'Agent_B'}
# Last message content: {'content': 'Understood, Leader. I appreciate the consideration of my latency requirements. A stable 80 Mbps allocation is a bit lower than what I initially requested, but if it can still maintain very low latency and minimal lag, I am willing to work with this.\n\nTo ensure that this works, we may need to closely monitor the performance during peak gaming hours to confirm that the latency remains within acceptable levels. If any issues arise, I would request a quick review to adjust as necessary.\n\nI believe this can be managed effectively with close monitoring and collaboration. Please let me know your thoughts, Leader. Over to you.', 'role': 'user', 'name': 'Agent_B'}
# LLM response: Leader
#
# Next speaker: Leader
#
#
# >>>>>>>> USING AUTO REPLY...
# [Leader] Sending message to chat_manager: {'content': 'Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.\n\nD, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.\n\nGiven the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:\n\n1. **A (Video Streaming)**\n   - 200 Mbps during peak hours\n   - 150 Mbps during non-peak hours\n\n2. **B (Online Gaming)**\n   - Stable 80 Mbps with a focus on low latency\n\n3. **C (Emergency Services)**\n   - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss\n\n4. **D (IoT Network Management)**\n   - Stable 20 Mbps with minimal jitter\n\nAll critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.\n\n**TERMINATE**\n\nThank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Info: Tool-related message sent and not stored in memory: {'content': 'Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.\n\nD, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.\n\nGiven the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:\n\n1. **A (Video Streaming)**\n   - 200 Mbps during peak hours\n   - 150 Mbps during non-peak hours\n\n2. **B (Online Gaming)**\n   - Stable 80 Mbps with a focus on low latency\n\n3. **C (Emergency Services)**\n   - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss\n\n4. **D (IoT Network Management)**\n   - Stable 20 Mbps with minimal jitter\n\nAll critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.\n\n**TERMINATE**\n\nThank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}
# Leader (to chat_manager):
#
# Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.
#
# D, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.
#
# Given the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:
#
# 1. **A (Video Streaming)**
#    - 200 Mbps during peak hours
#    - 150 Mbps during non-peak hours
#
# 2. **B (Online Gaming)**
#    - Stable 80 Mbps with a focus on low latency
#
# 3. **C (Emergency Services)**
#    - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss
#
# 4. **D (IoT Network Management)**
#    - Stable 20 Mbps with minimal jitter
#
# All critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.
#
# **TERMINATE**
#
# Thank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.
#
# --------------------------------------------------------------------------------
# [Agent_A] Received message from chat_manager: {'content': 'Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.\n\nD, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.\n\nGiven the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:\n\n1. **A (Video Streaming)**\n   - 200 Mbps during peak hours\n   - 150 Mbps during non-peak hours\n\n2. **B (Online Gaming)**\n   - Stable 80 Mbps with a focus on low latency\n\n3. **C (Emergency Services)**\n   - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss\n\n4. **D (IoT Network Management)**\n   - Stable 20 Mbps with minimal jitter\n\nAll critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.\n\n**TERMINATE**\n\nThank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.', 'role': 'user', 'name': 'Leader'}
# [Agent_B] Received message from chat_manager: {'content': 'Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.\n\nD, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.\n\nGiven the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:\n\n1. **A (Video Streaming)**\n   - 200 Mbps during peak hours\n   - 150 Mbps during non-peak hours\n\n2. **B (Online Gaming)**\n   - Stable 80 Mbps with a focus on low latency\n\n3. **C (Emergency Services)**\n   - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss\n\n4. **D (IoT Network Management)**\n   - Stable 20 Mbps with minimal jitter\n\nAll critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.\n\n**TERMINATE**\n\nThank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.', 'role': 'user', 'name': 'Leader'}
# [Agent_C] Received message from chat_manager: {'content': 'Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.\n\nD, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.\n\nGiven the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:\n\n1. **A (Video Streaming)**\n   - 200 Mbps during peak hours\n   - 150 Mbps during non-peak hours\n\n2. **B (Online Gaming)**\n   - Stable 80 Mbps with a focus on low latency\n\n3. **C (Emergency Services)**\n   - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss\n\n4. **D (IoT Network Management)**\n   - Stable 20 Mbps with minimal jitter\n\nAll critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.\n\n**TERMINATE**\n\nThank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.', 'role': 'user', 'name': 'Leader'}
# [Agent_D] Received message from chat_manager: {'content': 'Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.\n\nD, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.\n\nGiven the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:\n\n1. **A (Video Streaming)**\n   - 200 Mbps during peak hours\n   - 150 Mbps during non-peak hours\n\n2. **B (Online Gaming)**\n   - Stable 80 Mbps with a focus on low latency\n\n3. **C (Emergency Services)**\n   - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss\n\n4. **D (IoT Network Management)**\n   - Stable 20 Mbps with minimal jitter\n\nAll critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.\n\n**TERMINATE**\n\nThank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.', 'role': 'user', 'name': 'Leader'}
# ChatResult(chat_id=None, chat_history=[{'content': 'Leader: Agents A,B,C,D, report your QoS needs now.\nNegotiate bandwidth so all critical requirements are met.\n', 'role': 'assistant', 'name': 'User_proxy'}, {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'name': 'Leader', 'role': 'user'}, {'content': "A, please state your current QoS needs and bandwidth request. B, C, D, you will follow in that order. Once we have all the information, we'll proceed with negotiations to ensure everyone's critical requirements are met. A, you're up first. Go ahead.", 'name': 'Leader', 'role': 'user'}, {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'name': 'Agent_A', 'role': 'user'}, {'content': "Agent A: Understood, Leader. For my video streaming service, I require a peak bandwidth of approximately 200 Mbps to maintain high-quality video transmission and a moderate latency to ensure smooth playback without significant buffering or lag. My critical requirements include maintaining this bandwidth during peak hours and ensuring that the network can handle sudden spikes in demand.\n\nI am flexible on the exact allocation as long as it meets these criteria. I'm ready to negotiate further once I hear from Agents B, C, and D. Over to you, Leader.", 'name': 'Agent_A', 'role': 'user'}, {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'name': 'Leader', 'role': 'user'}, {'content': "Thank you, A. Your requirements are noted. B, please state your QoS needs and bandwidth request. We'll then move on to C and D before we start the negotiation process. Go ahead, B.", 'name': 'Leader', 'role': 'user'}, {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'name': 'Agent_B', 'role': 'user'}, {'content': 'Understood, Leader. For my online gaming service, I require a stable 100 Mbps of bandwidth with very low latency, as this is critical for maintaining responsive gameplay and a smooth user experience. Latency is my highest priority to avoid any lag or delay that could impact the performance in real-time multiplayer environments.\n\nI am willing to work with the team to ensure that all critical requirements are met, but I must have a consistent connection with minimal latency to function effectively. Over to you, Leader.', 'name': 'Agent_B', 'role': 'user'}, {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, please state your QoS needs and bandwidth request. We'll then hear from D before moving on to the negotiation phase. Go ahead, C.", 'name': 'Leader', 'role': 'user'}, {'content': "Thank you, B. Your requirements for low latency and stable bandwidth are noted. C, pleas ...

# %%
last_message = group_chat.messages[-1] if group_chat.messages else None
if last_message:
    print("Final Message Content:", last_message['content'])
# Out:
# Final Message Content: Thank you, B. Your willingness to work with an 80 Mbps allocation is appreciated. We will indeed monitor the performance closely to ensure that latency remains within acceptable levels.
#
# D, your requirement of 20 Mbps for IoT network management is already within the available bandwidth and does not need adjustment. We will ensure that this stable and low-jitter bandwidth is provided to you at all times.
#
# Given the adjustments from A and B, and the confirmed requirements from C and D, we have the following allocation:
#
# 1. **A (Video Streaming)**
#    - 200 Mbps during peak hours
#    - 150 Mbps during non-peak hours
#
# 2. **B (Online Gaming)**
#    - Stable 80 Mbps with a focus on low latency
#
# 3. **C (Emergency Services)**
#    - Guaranteed 50 Mbps with the lowest possible latency and zero tolerance for packet loss
#
# 4. **D (IoT Network Management)**
#    - Stable 20 Mbps with minimal jitter
#
# All critical requirements are met, and the network allocation is stable. Therefore, I will now terminate this negotiation.
#
# **TERMINATE**
#
# Thank you, A, B, C, and D, for your cooperation. If any issues arise or if further adjustments are needed, please report back immediately.

# %%
def save_conversation_to_file(groupchat, filename="chat.txt"):
    """
    Save the entire conversation history to a specified file.

    Args:
        groupchat (GroupChat): The GroupChat instance containing the messages.
        filename (str): The name of the file to save the conversation history.
    """
    if not groupchat.messages:
        print("No messages in the group chat to save.")
        return

    # Compile the conversation history
    conversation_history = "\n".join(
        f"{msg['role']}: {msg['content']}" for msg in groupchat.messages
    )

    # Write the conversation history to the file
    with open(filename, "w", encoding="utf-8") as file:
        file.write(conversation_history)

    print(f"Conversation history saved to {filename}")
    
save_conversation_to_file(group_chat, filename="chat.txt")
# Out:
# Conversation history saved to chat.txt

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# Initialize the Llama 3.1 model
llm = ChatOpenAI(
    model="llama3.1",
    base_url="http://YOUR-OLLAMA-HOST:11434/v1"
)

def structure_logs_with_local_llm(file_path, initial_message):
    """
    Reads chat logs from a file and generates a structured summary.

    Args:
        file_path (str): Path to the chat log file.
        initial_message (str): The initial task or prompt for context.

    Returns:
        str: The structured summary generated by the LLM.
    """
    # Read the chat logs from the file
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            log_context = file.read()
    except FileNotFoundError:
        return "Error: The specified file was not found."
    except Exception as e:
        return f"An error occurred while reading the file: {e}"

    # Prepare the messages for the LLM
    messages = [
        {
            "role": "system",
            "content": (
                "You are a professional chat summarizer who goes through the entire chat and creates a proper summary based on the '{initial_message}'."
            )
        },
        {
            "role": "user",
            "content": (
                f"Convert the following agent logs into a structured format and into a proper summarized final output "
                f"based on the task '{initial_message}'.\n\nLogs:\n{log_context}"
            )
        }
    ]

    # Generate the structured summary using the LLM
    try:
        response = llm.invoke(messages)
        if isinstance(response, AIMessage):
            structured_summary = response.content
        else:
            structured_summary = "Unexpected response type from the model."
    except Exception as e:
        structured_summary = f"An error occurred during LLM processing: {e}"

    return structured_summary

# %%
# Define the path to your chat log file and the initial task message
file_path = 'chat.txt'
initial_message = 'Design a comprehensive digital marketing course.'

# Generate the structured summary
summary = structure_logs_with_local_llm(file_path, initial_message)

# Output the summary
print(summary)
# Out:
# An error occurred during LLM processing: Request timed out.
